# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# Generate a sequence of numbers from -10 to 10 with 100 steps inbetween
x = np.linspace(-10, 10, 100)

#create a second array using cosine
y = np.cos(x)

plt.plot(x, y, marker="x")
# Out:
# <img src="data:image/png;base64,..." width="989">

# %% [markdown]
# ## Cosine plotted.
